# %% [markdown]
# # Graph
#
# * Randomized MinCut

# %%
import random
import numpy as np

from copy import deepcopy

# %%
adj_list_path = "/home/jacobsuwang/Documents/CS TRAINING/ALGORITHMS/DATA/KargerMinCut.txt"

# %% [markdown]
# ### Preprocessing
#
# * Save edges to a list for sampling.
# * Make dict {v: [v, v, ...]}.

# %%
edges = []
adj_list = {}
with open(adj_list_path, 'r') as source:
    for line in source:
        line = line.split()
        u = line[0]
        for v in line[1:]:
            edges.append([u,v])
        adj_list[u] = line[1:]

# %% [markdown]
# ### Contraction
#
# * Randomly select $(u,v)$.
# * Delete $(u,v),(v,u)$.
# * Rename $u$ to $u-v$, append list of vertices of $v$ under $u-v$.

# %%
def contract(edges, adj_list):
    # sample edge
    u,v = random.choice(edges)
    # replace old nodes and edges in edge set
    new_node = u+'-'+v
    new_edges = []
    for a,b in edges:
        if [a,b]==[u,v] or [a,b]==[v,u]: continue
        if u==a or v==a:
            new_edges.append([new_node,b])
        elif u==b or v==b:
            new_edges.append([a,new_node])
        else:
            new_edges.append([a,b])
    # replace old nodes and edges in adjacent list
    new_list = adj_list[u] + adj_list[v]
    del adj_list[u], adj_list[v]
    adj_list[new_node] = new_list
    for node,ls in adj_list.iteritems():
        for i,elem in enumerate(ls):
            if elem==u or elem==v:
                adj_list[node][i] = new_node
    # delete self-loops
    for node,ls in adj_list.iteritems():
        new_ls = []
        for i,elem in enumerate(ls):
            if node!=elem:
                new_ls.append(elem)
        adj_list[node] = new_ls
    return new_edges, adj_list

# %%
test_adj_list = {'1':['2','3'],'2':['1','3','4'],'3':['1','2','4'],'4':['2','3']}
test_edges = []
for v,l in test_adj_list.iteritems():
    for elem in l:
        test_edges.append([v,elem])

print test_edges
print

while len(test_adj_list)>2:
    test_edges, test_adj_list = contract(test_edges, test_adj_list)
    
print test_edges
print
print test_adj_list
# Out:
# [['1', '2'], ['1', '3'], ['3', '1'], ['3', '2'], ['3', '4'], ['2', '1'], ['2', '3'], ['2', '4'], ['4', '2'], ['4', '3']]
#
# [['1', '2-4-3'], ['1', '2-4-3'], ['2-4-3', '1'], ['2-4-3', '1']]
#
# {'1': ['2-4-3', '2-4-3'], '2-4-3': ['1', '1']}

# %% [markdown]
# ### Count Crossing-Edges

# %%
def count_crossing(adj_list):
    return len(adj_list[adj_list.keys()[0]])

# %% [markdown]
# ### Run Fn.

# %%
def run(original_edges, original_adj_list, N, verbose=False):
    counts = []
    for i in range(N):
        edges, adj_list = deepcopy(original_edges), deepcopy(original_adj_list)
        while len(adj_list)>2:
            edges,adj_list = contract(edges,adj_list)
        count = count_crossing(adj_list)
        if verbose:
            print 'run', i, '#crossings =', count 
        counts.append(count)
    return counts

# %%
# test run

test_adj_list = {'1':['2','3'],'2':['1','3','4'],'3':['1','2','4'],'4':['2','3']}
test_edges = []
for v,l in test_adj_list.iteritems():
    for elem in l:
        test_edges.append([v,elem])
        
N = 100
counts = run(test_edges, test_adj_list, N)

print 'Min Cut:', min(counts)
# Out:
# Min Cut: 2

# %%
# format check

edges = []
adj_list = {}
with open(adj_list_path, 'r') as source:
    for line in source:
        line = line.split()
        u = line[0]
        for v in line[1:]:
            edges.append([u,v])
        adj_list[u] = line[1:]

while len(adj_list)>2:
    edges, adj_list = contract(edges, adj_list)

# %%
for v,l in adj_list.iteritems():
    print v, '|', len(l)
# Out:
# 44-63-149-97-141-134-2-128-16-194-112-67-41-49-139-121-79-192-129-138-101-106-142-111-172-146-12-179-187-136-74-94-173-153-11-163-90-92-30-17-66-3-48-88-70-47-181-29-191-59-195-184-117-158-166-58-52-99-133-113-42-156-137-120-193-124-151-81-150-27-86-26-178-45-160-38-31-9-100-57-64-22-32-108-56-144-140-84-175-1-8-145-126-71-96-87-6-107-14-78-125-118-4-102-155-85-75-68-152-157-13-169-95-21-188-154-159-82-51-105-168-104-143-116-33-36-147-165-110-77-167-50-130-72-109-197-54-123-189-182-103-148-164-198-135-35-39-15-127-46-98-190-91-19-80-23-122-196-20-119-89-55-93-73-25-76-37-18-171-34-200-162-114-161-10-61-186-65-69-131-28-199-83-180-177-60-62-185-7-115-174-24-170-5-53-132-40-43-183 | 21
# 176 | 21

# %%
# %%time

# serious run 1

edges = []
adj_list = {}
with open(adj_list_path, 'r') as source:
    for line in source:
        line = line.split()
        u = line[0]
        for v in line[1:]:
            edges.append([u,v])
        adj_list[u] = line[1:]

N = 200
counts = run(edges, adj_list, N, verbose=True)

print 'Min Cut:', min(counts)
# Out:
# run 0 #crossings = 25
# run 1 #crossings = 20
# run 2 #crossings = 20
# run 3 #crossings = 20
# run 4 #crossings = 20
# run 5 #crossings = 22
# run 6 #crossings = 20
# run 7 #crossings = 23
# run 8 #crossings = 20
# run 9 #crossings = 31
# run 10 #crossings = 21
# run 11 #crossings = 20
# run 12 #crossings = 21
# run 13 #crossings = 20
# run 14 #crossings = 27
# run 15 #crossings = 20
# run 16 #crossings = 20
# run 17 #crossings = 24
# run 18 #crossings = 26
# run 19 #crossings = 24
# run 20 #crossings = 21
# run 21 #crossings = 20
# run 22 #crossings = 21
# run 23 #crossings = 20
# run 24 #crossings = 23
# run 25 #crossings = 20
# run 26 #crossings = 26
# run 27 #crossings = 20
# run 28 #crossings = 20
# run 29 #crossings = 20
# run 30 #crossings = 23
# run 31 #crossings = 21
# run 32 #crossings = 27
# run 33 #crossings = 20
# run 34 #crossings = 24
# run 35 #crossings = 20
# run 36 #crossings = 24
# run 37 #crossings = 26
# run 38 #crossings = 20
# run 39 #crossings = 22
# run 40 #crossings = 23
# run 41 #crossings = 24
# run 42 #crossings = 21
# run 43 #crossings = 20
# run 44 #crossings = 20
# run 45 #crossings = 20
# run 46 #crossings = 22
# run 47 #crossings = 20
# run 48 #crossings = 31
# run 49 #crossings = 21
# run 50 #crossings = 26
# run 51 #crossings = 25
# run 52 #crossings = 20
# run 53 #crossings = 26
# run 54 #crossings = 28
# run 55 #crossings = 20
# run 56 #crossings = 20
# run 57 #crossings = 22
# run 58 #crossings = 22
# run 59 #crossings = 21
# run 60 #crossings = 20
# run 61 #crossings = 28
# run 62 #crossings = 22
# run 63 #crossings = 20
# run 64 #crossings = 21
# run 65 #crossings = 23
# run 66 #crossings = 20
# run 67 #crossings = 24
# run 68 #crossings = 20
# run 69 #crossings = 28
# run 70 #crossings = 20
# run 71 #crossings = 21
# run 72 #crossings = 23
# run 73 #crossings = 25
# run 74 #crossings = 20
# run 75 #crossings = 20
# run 76 #crossings = 20
# run 77 #crossings = 21
# run 78 #crossings = 23
# run 79 #crossings = 25
# run 80 #crossings = 23
# run 81 #crossings = 22
# run 82 #crossings = 20
# run 83 #crossings = 20
# run 84 #crossings = 21
# run 85 #crossings = 20
# run 86 #crossings = 21
# run 87 #crossings = 20
# run 88 #crossings = 26
# run 89 #crossings = 20
# run 90 #crossings = 21
# run 91 #crossings = 21
# run 92 #crossings = 20
# run 93 #crossings = 22
# run 94 #crossings = 22
# run 95 #crossings = 21
# run 96 #crossings = 21
# run 97 #crossings = 25
# run 98 #crossings = 17
# run 99 #crossings = 21
# run 100 #crossings = 26
# run 101 #crossings = 27
# run 102 #crossings = 24
# run 103 #crossings = 22
# run 104 #crossings = 20
# run 105 #crossings = 20
# run 106 #crossings = 20
# run 107 #crossings = 24
# run 108 #crossings = 22
# run 109 #crossings = 41
# run 110 #crossings = 20
# run 111 #crossings = 26
# run 112 #crossings = 21
# run 113 #crossings = 20
# run 114 #crossings = 28
# run 115 #crossings = 20
# run 116 #crossings = 27
# run 117 #crossings = 20
# run 118 #crossings = 23
# run 119 #crossings = 26
# run 120 #crossings = 28
# run 121 #crossings = 26
# run 122 #crossings = 20
# run 123 #crossings = 20
# run 124 #crossings = 21
# run 125 #crossings = 24
# run 126 #crossings = 26
# run 127 #crossings = 20
# run 128 #crossings = 21
# run 129 #crossings = 21
# run 130 #crossings = 20
# run 131 #crossings = 28
# run 132 #crossings = 24
# run 133 #crossings = 22
# run 134 #crossings = 27
# run 135 #crossings = 27
# run 136 #crossings = 24
# run 137 #crossings = 26
# run 138 #crossings = 31
# run 139 #crossings = 23
# run 140 #crossings = 22
# run 141 #crossings = 22
# run 142 #crossings = 17
# run 143 #crossings = 20
# run 144 #crossings = 24
# run 145 #crossings = 31
# run 146 #crossings = 21
# run 147 #crossings = 20
# run 148 #crossings = 31
# run 149 #crossings = 29
# run 150 #crossings = 23
# run 151 #crossings = 22
# run 152 #crossings = 24
# run 153 #crossings = 21
# run 154 #crossings = 20
# run 155 #crossings = 20
# run 156 #crossings = 23
# run 157 #crossings = 20
# run 158 #crossings = 20
# run 159 #crossings = 23
# run 160 #crossings = 20
# run 161 #crossings = 21
# run 162 #crossings = 22
# run 163 #crossings = 23
# run 164 #crossings = 20
# run 165 #crossings = 24
# run 166 #crossings = 21
# run 167 #crossings = 25
# run 168 #crossings = 28
# run 169 #crossings = 23
# run 170 #crossings = 20
# run 171 #crossings = 25
# run 172 #crossings = 22
# run 173 #crossings = 20
# run 174 #crossings = 24
# run 175 #crossings = 31
# run 176 #crossings = 20
# run 177 #crossings = 22
# run 178 #crossings = 20
# run 179 #crossings = 20
# run 180 #crossings = 21
# run 181 #crossings = 31
# run 182 #crossings = 22
# run 183 #crossings = 23
# run 184 #crossings = 25
# run 185 #crossings = 20
# run 186 #crossings = 23
# run 187 #crossings = 17
# run 188 #crossings = 26
# run 189 #crossings = 22
# run 190 #crossings = 20
# run 191 #crossings = 22
# run 192 #crossings = 22
# run 193 #crossings = 22
# run 194 #crossings = 20
# run 195 #crossings = 23
# run 196 #crossings = 21
# run 197 #crossings = 25
# run 198 #crossings = 24
# run 199 #crossings = 21
# Min Cut: 17
# CPU times: user 1min 41s, sys: 1.15 s, total: 1min 42s
# Wall time: 1min 39s

# %%
# %%time

# serious run 2

edges = []
adj_list = {}
with open(adj_list_path, 'r') as source:
    for line in source:
        line = line.split()
        u = line[0]
        for v in line[1:]:
            edges.append([u,v])
        adj_list[u] = line[1:]

N = 200
counts = run(edges, adj_list, N, verbose=True)

print 'Min Cut:', min(counts)
# Out:
# run 0 #crossings = 35
# run 1 #crossings = 22
# run 2 #crossings = 23
# run 3 #crossings = 24
# run 4 #crossings = 23
# run 5 #crossings = 25
# run 6 #crossings = 22
# run 7 #crossings = 20
# run 8 #crossings = 21
# run 9 #crossings = 20
# run 10 #crossings = 20
# run 11 #crossings = 22
# run 12 #crossings = 26
# run 13 #crossings = 22
# run 14 #crossings = 22
# run 15 #crossings = 24
# run 16 #crossings = 20
# run 17 #crossings = 20
# run 18 #crossings = 21
# run 19 #crossings = 21
# run 20 #crossings = 22
# run 21 #crossings = 25
# run 22 #crossings = 20
# run 23 #crossings = 23
# run 24 #crossings = 20
# run 25 #crossings = 26
# run 26 #crossings = 26
# run 27 #crossings = 20
# run 28 #crossings = 20
# run 29 #crossings = 30
# run 30 #crossings = 20
# run 31 #crossings = 20
# run 32 #crossings = 20
# run 33 #crossings = 20
# run 34 #crossings = 34
# run 35 #crossings = 22
# run 36 #crossings = 24
# run 37 #crossings = 22
# run 38 #crossings = 40
# run 39 #crossings = 27
# run 40 #crossings = 20
# run 41 #crossings = 27
# run 42 #crossings = 25
# run 43 #crossings = 22
# run 44 #crossings = 21
# run 45 #crossings = 21
# run 46 #crossings = 23
# run 47 #crossings = 20
# run 48 #crossings = 21
# run 49 #crossings = 20
# run 50 #crossings = 26
# run 51 #crossings = 20
# run 52 #crossings = 31
# run 53 #crossings = 24
# run 54 #crossings = 24
# run 55 #crossings = 24
# run 56 #crossings = 22
# run 57 #crossings = 20
# run 58 #crossings = 21
# run 59 #crossings = 20
# run 60 #crossings = 27
# run 61 #crossings = 17
# run 62 #crossings = 25
# run 63 #crossings = 21
# run 64 #crossings = 22
# run 65 #crossings = 46
# run 66 #crossings = 32
# run 67 #crossings = 20
# run 68 #crossings = 21
# run 69 #crossings = 48
# run 70 #crossings = 21
# run 71 #crossings = 24
# run 72 #crossings = 17
# run 73 #crossings = 24
# run 74 #crossings = 22
# run 75 #crossings = 21
# run 76 #crossings = 24
# run 77 #crossings = 20
# run 78 #crossings = 24
# run 79 #crossings = 23
# run 80 #crossings = 21
# run 81 #crossings = 20
# run 82 #crossings = 24
# run 83 #crossings = 27
# run 84 #crossings = 33
# run 85 #crossings = 20
# run 86 #crossings = 23
# run 87 #crossings = 20
# run 88 #crossings = 20
# run 89 #crossings = 20
# run 90 #crossings = 26
# run 91 #crossings = 26
# run 92 #crossings = 24
# run 93 #crossings = 43
# run 94 #crossings = 21
# run 95 #crossings = 22
# run 96 #crossings = 26
# run 97 #crossings = 24
# run 98 #crossings = 21
# run 99 #crossings = 20
# run 100 #crossings = 22
# run 101 #crossings = 22
# run 102 #crossings = 23
# run 103 #crossings = 22
# run 104 #crossings = 20
# run 105 #crossings = 20
# run 106 #crossings = 59
# run 107 #crossings = 21
# run 108 #crossings = 22
# run 109 #crossings = 20
# run 110 #crossings = 24
# run 111 #crossings = 20
# run 112 #crossings = 23
# run 113 #crossings = 20
# run 114 #crossings = 21
# run 115 #crossings = 20
# run 116 #crossings = 25
# run 117 #crossings = 20
# run 118 #crossings = 26
# run 119 #crossings = 21
# run 120 #crossings = 20
# run 121 #crossings = 21
# run 122 #crossings = 71
# run 123 #crossings = 23
# run 124 #crossings = 22
# run 125 #crossings = 20
# run 126 #crossings = 23
# run 127 #crossings = 24
# run 128 #crossings = 20
# run 129 #crossings = 21
# run 130 #crossings = 50
# run 131 #crossings = 45
# run 132 #crossings = 20
# run 133 #crossings = 22
# run 134 #crossings = 25
# run 135 #crossings = 21
# run 136 #crossings = 25
# run 137 #crossings = 22
# run 138 #crossings = 25
# run 139 #crossings = 24
# run 140 #crossings = 20
# run 141 #crossings = 43
# run 142 #crossings = 20
# run 143 #crossings = 21
# run 144 #crossings = 26
# run 145 #crossings = 20
# run 146 #crossings = 26
# run 147 #crossings = 22
# run 148 #crossings = 20
# run 149 #crossings = 21
# run 150 #crossings = 21
# run 151 #crossings = 26
# run 152 #crossings = 23
# run 153 #crossings = 23
# run 154 #crossings = 20
# run 155 #crossings = 21
# run 156 #crossings = 27
# run 157 #crossings = 26
# run 158 #crossings = 20
# run 159 #crossings = 27
# run 160 #crossings = 28
# run 161 #crossings = 22
# run 162 #crossings = 20
# run 163 #crossings = 20
# run 164 #crossings = 26
# run 165 #crossings = 25
# run 166 #crossings = 21
# run 167 #crossings = 24
# run 168 #crossings = 20
# run 169 #crossings = 21
# run 170 #crossings = 26
# run 171 #crossings = 20
# run 172 #crossings = 17
# run 173 #crossings = 21
# run 174 #crossings = 20
# run 175 #crossings = 20
# run 176 #crossings = 21
# run 177 #crossings = 31
# run 178 #crossings = 24
# run 179 #crossings = 20
# run 180 #crossings = 24
# run 181 #crossings = 21
# run 182 #crossings = 29
# run 183 #crossings = 20
# run 184 #crossings = 20
# run 185 #crossings = 22
# run 186 #crossings = 22
# run 187 #crossings = 28
# run 188 #crossings = 22
# run 189 #crossings = 22
# run 190 #crossings = 22
# run 191 #crossings = 26
# run 192 #crossings = 20
# run 193 #crossings = 20
# run 194 #crossings = 20
# run 195 #crossings = 17
# run 196 #crossings = 20
# run 197 #crossings = 24
# run 198 #crossings = 26
# run 199 #crossings = 30
# Min Cut: 17
# CPU times: user 1min 41s, sys: 1.21 s, total: 1min 42s
# Wall time: 1min 39s

# %%
# %%time

# serious run 3

edges = []
adj_list = {}
with open(adj_list_path, 'r') as source:
    for line in source:
        line = line.split()
        u = line[0]
        for v in line[1:]:
            edges.append([u,v])
        adj_list[u] = line[1:]

N = 200
counts = run(edges, adj_list, N, verbose=True)

print 'Min Cut:', min(counts)
# Out:
# run 0 #crossings = 26
# run 1 #crossings = 26
# run 2 #crossings = 22
# run 3 #crossings = 20
# run 4 #crossings = 23
# run 5 #crossings = 17
# run 6 #crossings = 48
# run 7 #crossings = 20
# run 8 #crossings = 21
# run 9 #crossings = 17
# run 10 #crossings = 23
# run 11 #crossings = 21
# run 12 #crossings = 31
# run 13 #crossings = 28
# run 14 #crossings = 21
# run 15 #crossings = 20
# run 16 #crossings = 20
# run 17 #crossings = 28
# run 18 #crossings = 17
# run 19 #crossings = 22
# run 20 #crossings = 23
# run 21 #crossings = 22
# run 22 #crossings = 20
# run 23 #crossings = 25
# run 24 #crossings = 21
# run 25 #crossings = 24
# run 26 #crossings = 24
# run 27 #crossings = 20
# run 28 #crossings = 25
# run 29 #crossings = 21
# run 30 #crossings = 24
# run 31 #crossings = 26
# run 32 #crossings = 20
# run 33 #crossings = 21
# run 34 #crossings = 22
# run 35 #crossings = 22
# run 36 #crossings = 28
# run 37 #crossings = 20
# run 38 #crossings = 24
# run 39 #crossings = 21
# run 40 #crossings = 24
# run 41 #crossings = 24
# run 42 #crossings = 22
# run 43 #crossings = 26
# run 44 #crossings = 17
# run 45 #crossings = 24
# run 46 #crossings = 21
# run 47 #crossings = 20
# run 48 #crossings = 27
# run 49 #crossings = 23
# run 50 #crossings = 21
# run 51 #crossings = 28
# run 52 #crossings = 21
# run 53 #crossings = 21
# run 54 #crossings = 20
# run 55 #crossings = 21
# run 56 #crossings = 24
# run 57 #crossings = 27
# run 58 #crossings = 17
# run 59 #crossings = 22
# run 60 #crossings = 21
# run 61 #crossings = 20
# run 62 #crossings = 20
# run 63 #crossings = 22
# run 64 #crossings = 20
# run 65 #crossings = 27
# run 66 #crossings = 24
# run 67 #crossings = 20
# run 68 #crossings = 22
# run 69 #crossings = 24
# run 70 #crossings = 25
# run 71 #crossings = 20
# run 72 #crossings = 20
# run 73 #crossings = 22
# run 74 #crossings = 20
# run 75 #crossings = 22
# run 76 #crossings = 29
# run 77 #crossings = 22
# run 78 #crossings = 22
# run 79 #crossings = 20
# run 80 #crossings = 20
# run 81 #crossings = 20
# run 82 #crossings = 21
# run 83 #crossings = 22
# run 84 #crossings = 20
# run 85 #crossings = 20
# run 86 #crossings = 25
# run 87 #crossings = 22
# run 88 #crossings = 22
# run 89 #crossings = 21
# run 90 #crossings = 25
# run 91 #crossings = 25
# run 92 #crossings = 27
# run 93 #crossings = 22
# run 94 #crossings = 27
# run 95 #crossings = 26
# run 96 #crossings = 20
# run 97 #crossings = 24
# run 98 #crossings = 26
# run 99 #crossings = 25
# run 100 #crossings = 22
# run 101 #crossings = 34
# run 102 #crossings = 20
# run 103 #crossings = 24
# run 104 #crossings = 20
# run 105 #crossings = 23
# run 106 #crossings = 22
# run 107 #crossings = 23
# run 108 #crossings = 23
# run 109 #crossings = 24
# run 110 #crossings = 23
# run 111 #crossings = 20
# run 112 #crossings = 20
# run 113 #crossings = 21
# run 114 #crossings = 22
# run 115 #crossings = 20
# run 116 #crossings = 20
# run 117 #crossings = 23
# run 118 #crossings = 25
# run 119 #crossings = 20
# run 120 #crossings = 20
# run 121 #crossings = 22
# run 122 #crossings = 26
# run 123 #crossings = 23
# run 124 #crossings = 24
# run 125 #crossings = 20
# run 126 #crossings = 21
# run 127 #crossings = 27
# run 128 #crossings = 20
# run 129 #crossings = 21
# run 130 #crossings = 21
# run 131 #crossings = 33
# run 132 #crossings = 20
# run 133 #crossings = 20
# run 134 #crossings = 21
# run 135 #crossings = 20
# run 136 #crossings = 21
# run 137 #crossings = 34
# run 138 #crossings = 20
# run 139 #crossings = 20
# run 140 #crossings = 31
# run 141 #crossings = 26
# run 142 #crossings = 27
# run 143 #crossings = 20
# run 144 #crossings = 22
# run 145 #crossings = 20
# run 146 #crossings = 24
# run 147 #crossings = 27
# run 148 #crossings = 26
# run 149 #crossings = 25
# run 150 #crossings = 21
# run 151 #crossings = 25
# run 152 #crossings = 22
# run 153 #crossings = 21
# run 154 #crossings = 22
# run 155 #crossings = 23
# run 156 #crossings = 17
# run 157 #crossings = 20
# run 158 #crossings = 23
# run 159 #crossings = 29
# run 160 #crossings = 22
# run 161 #crossings = 23
# run 162 #crossings = 21
# run 163 #crossings = 20
# run 164 #crossings = 21
# run 165 #crossings = 20
# run 166 #crossings = 20
# run 167 #crossings = 21
# run 168 #crossings = 24
# run 169 #crossings = 25
# run 170 #crossings = 34
# run 171 #crossings = 20
# run 172 #crossings = 21
# run 173 #crossings = 20
# run 174 #crossings = 21
# run 175 #crossings = 20
# run 176 #crossings = 20
# run 177 #crossings = 25
# run 178 #crossings = 22
# run 179 #crossings = 17
# run 180 #crossings = 22
# run 181 #crossings = 20
# run 182 #crossings = 24
# run 183 #crossings = 20
# run 184 #crossings = 20
# run 185 #crossings = 20
# run 186 #crossings = 24
# run 187 #crossings = 20
# run 188 #crossings = 21
# run 189 #crossings = 20
# run 190 #crossings = 20
# run 191 #crossings = 21
# run 192 #crossings = 20
# run 193 #crossings = 17
# run 194 #crossings = 23
# run 195 #crossings = 26
# run 196 #crossings = 20
# run 197 #crossings = 20
# run 198 #crossings = 29
# run 199 #crossings = 26
# Min Cut: 17
# CPU times: user 1min 41s, sys: 1.26 s, total: 1min 43s
# Wall time: 1min 40s
